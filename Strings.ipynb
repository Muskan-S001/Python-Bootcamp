# %%
st = "Muskan"
rev = ""
length = len(st)
i = 1
while i<=length:
    s = st[length - i]
    rev = rev + s
    i += 1
print(rev)
# Out:
# 6
# naksuM

# %%
st
# Out:
# 'Muskan'

# %%
inputt = "Muskan"
rev = ""
i = len(inputt)-1
while i>=0:
    s = inputt[i]
    rev = rev + s
    i-=1    
print(rev)

# %%
s = input()

# %%
inputt = input()
rev = ""
i = len(inputt)-1
while i>=0:
    s = inputt[i]
    rev = rev + s
    i-=1    
if rev == inputt:
    print(True)
else:
    print(False)
# Out:
#  racecar
# True

# %%
s = input()
flag = True
i = 0
j = len(s) - 1
while i < j:
    m = s[i]
    t = s[j]
    if m != t:
        flag = False
        break
    i +=1
    j -=1
print(flag)
# Out:
#  racecar
# True
